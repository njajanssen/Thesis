# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
d = pd.read_csv('catsup.txt', delimiter=' ')

# %%
d.head(15)
# Out:
#     id  disp.heinz41  disp.heinz32  disp.heinz28  disp.hunts32  feat.heinz41  \
# 1    1             0             0             0             0             0
# 2    1             0             0             0             0             0
# 3    1             0             0             0             0             0
# 4    1             0             0             0             0             0
# 5    1             0             0             0             0             0
# 6    1             0             0             0             0             0
# 7    1             0             0             0             1             0
# 8    1             0             0             0             0             0
# 9    1             0             0             0             0             0
# 10   1             0             0             0             1             0
# 11   1             0             0             0             0             0
# ...

# %%
d['choice'].value_counts()
# Out:
# heinz32    1458
# heinz28     851
# hunts32     307
# heinz41     182
# Name: choice, dtype: int64

# %%
d['id'].value_counts()
# Out:
# 160    44
# 277    40
# 107    28
# 257    28
# 27     26
# 294    24
# 211    23
# 94     22
# 168    22
# 15     22
# 180    22
# 127    22
# 51     22
# 185    21
# 112    21
# 162    20
# 3      20
# 244    20
# 249    19
# 192    18
# 124    18
# 64     18
# 269    17
# 199    17
# 245    17
# 36     16
# 263    16
# 115    16
# 187    15
# 189    15
#        ..
# 83      5
# 81      5
# 174     5
# 75      5
# 73      5
# 136     5
# 134     5
# 182     5
# 121     5
# 67      5
# 126     5
# 188     5
# 133     5
# 194     5
# 222     5
# 149     5
# 198     5
# 41      5
# 104     5
# 165     5
# 167     5
# 96      5
# 208     5
# 212     5
# 214     5
# 191     5
# 84      5
# 207     5
# 74      5
# 117     5
# Name: id, Length: 300, dtype: int64

# %%
d['choice'] = d['choice'].map({'heinz41': 0, 'heinz32': 1, 'heinz28':2, 'hunts32':3})
d.head()
# Out:
#    id  disp.heinz41  disp.heinz32  disp.heinz28  disp.hunts32  feat.heinz41  \
# 1   1             0             0             0             0             0
# 2   1             0             0             0             0             0
# 3   1             0             0             0             0             0
# 4   1             0             0             0             0             0
# 5   1             0             0             0             0             0
#
#    feat.heinz32  feat.heinz28  feat.hunts32  price.heinz41  price.heinz32  \
# 1             0             0             0            4.6            3.7
# 2             0             0             0            4.6            4.3
# 3             1             0             0            4.6            2.5
# 4             0             0             0            4.6            3.7
# 5             0             1             0            4.6            3.0
#
#    price.heinz28  price.hunts32  choice
# ...

# %%
d.to_csv('catsup.csv')

# %%
for column in d:
    print(column)
    d[column].value_counts().sort_index().plot.bar(color='b')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f7093ba5ff32> in <module>
# ----> 1 for column in d:
#       2     print(column)
#       3     d[column].value_counts().sort_index().plot.bar(color='b')
#       4     plt.show()
#
# NameError: name 'd' is not defined

# %%
d_np = d.values

# %%
np.save('data.npy', d_np)

# %%
catsup = pd.DataFrame(columns=['chosen', 'id', 'alt', 'display', 'feature', 'price', 'chid'])
alt = []
for i in range(2798):
    alt.append([0,1,2,3])
alt = [item for sublist in alt for item in sublist]
catsup['alt'] = chid
catsup.head(10)
# Out:
#   chosen   id  alt display feature price chid
# 0    NaN  NaN    0     NaN     NaN   NaN  NaN
# 1    NaN  NaN    1     NaN     NaN   NaN  NaN
# 2    NaN  NaN    2     NaN     NaN   NaN  NaN
# 3    NaN  NaN    3     NaN     NaN   NaN  NaN
# 4    NaN  NaN    0     NaN     NaN   NaN  NaN
# 5    NaN  NaN    1     NaN     NaN   NaN  NaN
# 6    NaN  NaN    2     NaN     NaN   NaN  NaN
# 7    NaN  NaN    3     NaN     NaN   NaN  NaN
# 8    NaN  NaN    0     NaN     NaN   NaN  NaN
# 9    NaN  NaN    1     NaN     NaN   NaN  NaN

# %%
chid = [4*[j] for j in range(2798)]
chid = [item for sublist in chid for item in sublist]
catsup['chid'] = chid
catsup.head()
# Out:
#   chosen   id  alt display feature price  chid
# 0    NaN  NaN    0     NaN     NaN   NaN     0
# 1    NaN  NaN    1     NaN     NaN   NaN     0
# 2    NaN  NaN    2     NaN     NaN   NaN     0
# 3    NaN  NaN    3     NaN     NaN   NaN     0
# 4    NaN  NaN    0     NaN     NaN   NaN     1

# %%
chosen = np.zeros([11192,1])
i = 0
for choice in d['choice']:
    for i in range(4):
        if i == choice:
            chosen[i] == True
        else:
            chosen[i] == False
# Out:
# array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [0.],
#        [0.],
#        [0.]])
